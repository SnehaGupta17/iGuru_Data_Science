# %%
# Exploratory Data Analysis [EDA]
# Exploratory Data Analysis refers to the critical process of 
# performing initial investigations on data so as to discover patterns,
# to spot anomalies,to test hypothesis and to check assumptions 
# with the help of summary statistics and graphical representations.
 
# It is a good practice to understand the data first and try to gather
# as many insights from it.
 
# Exploratory data analysis (EDA) is used by data scientists to analyze 
# and investigate data sets and summarize their main characteristics, 
# often employing data visualization methods.
 
# The main purpose of EDA is to help look at data before making any 
# assumptions. It can help identify obvious errors, as well as better 
# understand patterns within the data, detect outliers or 
# anomalous events, find interesting relations among the variables.
 
# Dataset : https://raw.githubusercontent.com/yash240990/Python/master/telecom_churn.csv

# %%
#import all necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Load the dataset
data = pd.read_csv('https://raw.githubusercontent.com/yash240990/Python/master/telecom_churn.csv')
data
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
# #To display all data
# pd.options.display.max_rows = None
# pd.options.display.max_columns = None

# %%
# # #astype() ----convert bool to int
# data['churn'] = data['churn'].astype('int64')
# data['churn']

# %%
data.columns
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %%
data.shape
# Out:
# (3333, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %%
#astype() ----convert bool to int
data['churn']=data['churn'].astype('int64')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %%
#shows the statistical summary of dataset
#by default it will show the summary of numerical feature
data.describe()
# 25% -- 25% of data have the value 143(total day minutes) or below
# 50% -- 50% of data have the value 179 or below
# 75% -- 75% of data have the value 216 or below
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
# in order to show statistical summary of non numerical features
# we need to use include parameter

data.describe(include='object')

# top -- value that has repeated multi[ple times
# Out:
#        state phone number international plan voice mail plan
# count   3333         3333               3333            3333
# unique    51         3333                  2               2
# top       WV     382-4657                 no              no
# freq     106            1               3010            2411

# %%
#value_counts()
#returns a count of unique values
data['international plan'].value_counts()
# Out:
# international plan
# no     3010
# yes     323
# Name: count, dtype: int64

# %%
# generate graph
sns.countplot(x ='international plan', data = data)
plt.title('international plan summary')
plt.show()

# %%
# Missing value calculation
# isnull() used to identify null values in dataset
#return TRUE if found any missing value
print(data.isnull())
print()
print("Missing values in separate col: \n",data.isnull().sum())
print()
print("Total missing values in table:",data.isnull().sum().sum())

# hence no missing value
# Out:
#       state  account length  area code  phone number  international plan  \
# 0     False           False      False         False               False
# 1     False           False      False         False               False
# 2     False           False      False         False               False
# 3     False           False      False         False               False
# 4     False           False      False         False               False
# ...     ...             ...        ...           ...                 ...
# 3328  False           False      False         False               False
# 3329  False           False      False         False               False
# 3330  False           False      False         False               False
# 3331  False           False      False         False               False
# 3332  False           False      False         False               False
#
#       voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
# check for duplicate values
data.duplicated().sum()
# Out:
# 0

# %%
#Selecting DataFrame
#If we want to work on only one column and not on whole table
#if there is space or no space in column name
data['phone number'].head(10)
# Out:
# 0    382-4657
# 1    371-7191
# 2    358-1921
# 3    375-9999
# 4    330-6626
# 5    391-8027
# 6    355-9993
# 7    329-9001
# 8    335-4719
# 9    330-8173
# Name: phone number, dtype: object

# %%
data.columns
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %%
# if there is no space in column name
data.state.head(5)
# Out:
# 0    KS
# 1    OH
# 2    NJ
# 3    OH
# 4    OK
# Name: state, dtype: object

# %%
data[['phone number','customer service calls','churn']].head(50)
# Out:
#    phone number  customer service calls  churn
# 0      382-4657                       1      0
# 1      371-7191                       1      0
# 2      358-1921                       0      0
# 3      375-9999                       2      0
# 4      330-6626                       3      0
# 5      391-8027                       0      0
# 6      355-9993                       3      0
# 7      329-9001                       0      0
# 8      335-4719                       1      0
# 9      330-8173                       0      0
# 10     329-6603                       4      1
# 11     344-9403                       0      0
# 12     363-1107                       1      0
# 13     394-8006                       3      0
# 14     366-9238                       4      0
# 15     351-7269                       4      1
# 16     350-8884                       1      0
# 17     386-2923                       3      0
# 18     356-2992                       1      0
# ...

# %%
data.columns
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %%
data[['phone number','total day calls','churn']].head(50)
# Out:
#    phone number  total day calls  churn
# 0      382-4657              110      0
# 1      371-7191              123      0
# 2      358-1921              114      0
# 3      375-9999               71      0
# 4      330-6626              113      0
# 5      391-8027               98      0
# 6      355-9993               88      0
# 7      329-9001               79      0
# 8      335-4719               97      0
# 9      330-8173               84      0
# 10     329-6603              137      1
# 11     344-9403              127      0
# 12     363-1107               96      0
# 13     394-8006               88      0
# 14     366-9238               70      0
# 15     351-7269               67      1
# 16     350-8884              139      0
# 17     386-2923              114      0
# 18     356-2992               66      0
# 19     373-2782               90      0
# 20     396-5800              117      0
# 21     393-7984               89      1
# ...

# %%
data[['phone number','total day calls','customer service calls','churn']].head(50)
# Out:
#    phone number  total day calls  customer service calls  churn
# 0      382-4657              110                       1      0
# 1      371-7191              123                       1      0
# 2      358-1921              114                       0      0
# 3      375-9999               71                       2      0
# 4      330-6626              113                       3      0
# 5      391-8027               98                       0      0
# 6      355-9993               88                       3      0
# 7      329-9001               79                       0      0
# 8      335-4719               97                       1      0
# 9      330-8173               84                       0      0
# 10     329-6603              137                       4      1
# 11     344-9403              127                       0      0
# 12     363-1107               96                       1      0
# 13     394-8006               88                       3      0
# ...

# %%
#sort_values()
#by default the data will be sorted in ascending order
data.sort_values(by='total day calls').head(50)
# Out:
#      state  account length  area code phone number international plan  \
# 1397    VT             101        510     413-7655                 no
# 1345    SD              98        415     392-2555                 no
# 1144    NH             155        408     353-6300                 no
# 1989    MT             124        415     420-5652                 no
# 692     NE              82        408     343-2741                 no
# 740     UT              67        510     414-9027                 no
# 3187    WV              58        408     391-6558                 no
# 1322    DE               2        415     415-8448                yes
# 2217    CA             137        415     415-3689                 no
# 2964    OR              99        408     353-3372                 no
# 2885    HI             135        415     333-4492                 no
# 2884    UT             170        415     397-6542                 no
# ...

# %%
data.sort_values(by='total day minutes',ascending=False).head(50)
# for Descending order
# Out:
#      state  account length  area code phone number international plan  \
# 365     CO             154        415     343-5709                 no
# 985     NY              64        415     345-9140                yes
# 2594    OH             115        510     348-1163                yes
# 156     OH              83        415     370-9116                 no
# 605     MO             112        415     373-2053                 no
# 975     DE             129        510     332-6181                 no
# 15      NY             161        415     351-7269                 no
# 1679    OK              82        510     393-4823                 no
# 2028    SD              93        510     408-4836                 no
# 197     TX             208        510     378-3625                 no
# 2412    WI              89        415     373-4264                 no
# 2824    OR              81        415     406-4100                 no
# ...

# %%
#how much on an average active users spend of phone calls during day time
data[data['churn']==0]['total day minutes'].mean()
# Out:
# 175.1757543859649

# %%
#how much on an average churn users spend of phone calls during day time
data[data['churn']==1]['total day minutes'].mean()
# Out:
# 206.91407867494823

# %%
#how much on an average active users spend of phone calls during night time
data[data['churn']==0]['total night minutes'].mean()
# Out:
# 200.13319298245614

# %%
#how much on an average churn users spend of phone calls during night time
data[data['churn']==1]['total night minutes'].mean()
# Out:
# 205.23167701863352
