# %%
from urllib.request import urlopen

# %%
url="https://www.collegedekho.com/engineering/colleges-in-haveri/"

# %%
response=urlopen(url)

# %%
import requests

# %%
url="https://www.collegedekho.com/engineering/colleges-in-haveri/"

# %%
res=requests.get(url)

# %%
res
# Out:
# <Response [200]>

# %%
# !pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup
url="https://www.collegedekho.com/engineering/colleges-in-haveri/"
res=requests.get(url)

# %%
soup=BeautifulSoup(res.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
# title -- help to get title of website
title=soup.title
title
# Out:
# <title class="title-seo">Top Engineering Colleges in Haveri 2025: Ranking, Fees, Placements 2025</title>

# %%
# find first h1 tag
print(soup.find('h1'))
# Out:
# <h1 id="page-h2">
#
#                        Top Engineering Colleges in Haveri 2025
#                     </h1>
