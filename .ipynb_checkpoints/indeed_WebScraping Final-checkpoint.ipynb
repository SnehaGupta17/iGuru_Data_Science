# %%
# !pip install selenium

# %%
import pandas as pd
import requests
import random
from bs4 import BeautifulSoup
import selenium                     # automate web browser
from selenium import webdriver      # it will use browser from your machine
import time

# %%
def get_url(position,location):
    position = position.replace(' ','+')
    location = location.replace(' ','+')
    template = 'https://in.indeed.com/jobs?q={}&l={}'
    url = template.format(position,location)
    return url

# %%
url = get_url('python','pune')
print(url)
# Out:
# https://in.indeed.com/jobs?q=python&l=pune

# %%
options = webdriver.ChromeOptions()
options.add_argument("--disable-blink-features=AutomationControlled")
driver = webdriver.Chrome(options=options)
driver.get(url)

# %%
time.sleep(5)

# %%
driver.title
# Out:
# '2,000 Python Job Vacancies in Pune, Maharashtra | Indeed'

# %%
driver.page_source
# Out:
# '<html dir="ltr" lang="en" class="js-focus-visible" data-js-focus-visible=""><head>\n    <link rel="shortcut icon" href="/images/favicon.ico">\n    <title>2,000 Python Job Vacancies in Pune, Maharashtra | Indeed</title>\n    <meta http-equiv="content-type" content="text/html; charset=utf-8">\n    <meta name="description" content="2,735 Python jobs available in Pune, Maharashtra on Indeed.com.">\n    \n    <meta name="referrer" content="origin-when-cross-origin">\n    \n\n    \n    \n    \n    \n    \n        <link rel="next" href="/jobs?q=python&amp;l=pune&amp;jlid=dd616958bd9ddc12&amp;forceLocation=-1&amp;start=10">\n    \n\n    \n        <link rel="canonical" href="https://in.indeed.com/q-python-l-pune,-maharashtra-jobs.html">\n    \n    \n        <link rel="alternate" href="android-app://com.indeed.android.jobsearch/https/in.indeed.com/m/jobs?q=python&amp;l=pune">\n    \n    \n        <link rel="alternate" href="ios-app://https/in.indeed.com/m/jobs?q=python&amp;l=pune">\n    \n    \n        <link rel="alternate" type="application/rss+xml" title="python Jobs, Employment in Pune, Maharashtra" href="http://in.indeed.com/rss?q=python&amp;l=pune&amp;radius=25">\n    \n    \n        \n        \n        \n            <meta name="viewport" content="width=device-width,initial-scale=1.0">\n        \n    \n    <meta name="format-detection" content="telephone=no">\n\n\n    <style>\n        html body *, html body div .gnav * { font-family: \'Noto Sans\', \'Helvetica Neue\', Helvetica, Arial, sans-serif !important; }\n    </style>\n\n    \n        <link rel="stylesheet" href="//c03.s3.indeed.com/m/s/86533e0116b31d7e4ea1/styles/current/serpWithOpenvjGlobal.css">\n    \n\n    <script type="text/javascript" async="" src="https://sgtm.indeed.com/gtag/js?id=G-LYNT3BTHPG&amp;l=dataLayer&amp;cx=c&amp;gtm=45Fe52q0v9177627461za204&amp;sign=c1933b49ea8074e91ed68a3c4ac220ee7f09c2afb6bd8dfc91e23b1c48755e0f_20250302&amp;tag_exp=101732282~101732284~102067808~102482433~102539968~102558064~102587591~102605417~102640600~102658453~102717421~102732003"></script><script async="" src="https://sgtm.indeed.com/gtm.js?id=GTM-M7N65VVK"></script><script id="mobile-shared-dep-modules">\n        window._INDEED = window._INDEED || {};\n        window._INDEED.modules = [{"container":"mobileSharedDeps","module":".\\u002FSerpWithOpenDynamicVjGlobal","shareScope":"react18_ifl6","urls":["\\u002F\\u002Fc03.s3.indeed.com\\u002Fm\\u002Fs\\u002Fscripts\\u002Freact18_ifl6\\u002FmobileSharedDeps.remoteEntry.06628f9e50561439bd87.js"]}];\n        (()=>{"use strict";window.addEventListener("DOMContentLoaded",(()=>{window._INDEED&&window._INDEED.modules&&window._INDEED.modules.forEach((d=>{const o=()=>{var o,e;null===(e=null===(o=window._INDEED)||void 0===o?void 0:o.shared)||void 0===e||e.v1.load("module",d)};window._INDEED&&window._INDEED.shared&&window._INDEED.shared.v1?o():window.addEventListener("onSharedDepsLoadersV1Available",o,{once:!0})}))}))})();\n    </script>\n    \n        \n            <link rel="preload" href="//c03.s3.indeed.com/m/s/scripts/react18_ifl6/mobileSharedDeps.remoteEntry.06628f9e50561439bd87.js" as="script" crossorigin="anonymous">\n        \n    \n    \n        <script async="" src="https://c03.s3.indeed.com/shared/sharedDepsLoadersV1.autoupgrade.js" crossorigin="anonymous"></script><link href="https://c03.s3.indeed.com/shared/react17/remoteEntry.autoupgrade.js" as="script" crossorigin="anonymous" rel="preload"><link href="https://c03.s3.indeed.com/shared/react18/remoteEntry.autoupgrade.js" as="script" crossorigin="anonymous" rel="preload"><link href="https://c03.s3.indeed.com/shared/react18_ifl6/remoteEntry.autoupgrade.js" as="script" crossorigin="anonymous" rel="preload"><link href="https://c03.s3.indeed.com/dist/header/remoteEntry.c55d802fc94e76cba04a.js" as="script" crossorigin="anonymous" rel="preload"><link href="https://c03.s3.indeed.com/dist/footer/remoteEntry.38ab817d9e96535230f9.js" as="script" crossorigin="anonymous" rel="preload"><script asyn ...

# %%
soup = BeautifulSoup(driver.page_source,'html.parser')

# %%
cards = soup.find_all('li','css-1ac2h1w eu4oa1w0')
print(len(cards))
# Out:
# 19

# %%
# Find the job listings container
job_container = soup.find('div', id='mosaic-provider-jobcards')

# %%
# Find job cards
cards = job_container.find_all('li', class_='css-1ac2h1w eu4oa1w0') if job_container else []

print(f"Found {len(cards)} job listings")

# Extract job details
jobs = []
for card in cards:
    # Job Title
    title_tag = card.find('h2', class_='jobTitle')
    job_title = title_tag.text.strip() if title_tag else "Not Available"

    # Company Name
    company_tag = card.find('span', {'data-testid': 'company-name'})
    company = company_tag.text.strip() if company_tag else "Not Available"

    # Salary
    salary_tag = card.find('div', {'data-testid': 'attribute_snippet_testid'})
    salary = salary_tag.text.strip() if salary_tag else "Not Provided"
    
    # Location
    location_tag = card.find('div', {'data-testid': 'text-location'})
    location = location_tag.text.strip() if location_tag else "Not Available"

    # Append job details
    jobs.append({"Job Title": job_title, "Company": company, "Salary": salary, "Location": location})
# Out:
# Found 19 job listings

# %%
# Convert to DataFrame
df = pd.DataFrame(jobs)
df.to_csv("indeed_jobs_final.csv", index=False)

# %%
# Display the first few results
df.head(10)
# Out:
#                      Job Title                                  Company  \
# 0                Not Available                            Not Available
# 1     Senior software engineer                                BP Energy
# 2  Software Developer (Python)                                Predis.ai
# 3              python devloper                                 TalentXo
# 4             Python Developer                      Distinct Cloud Labs
# 5             Python Developer  Natobotics Technologies Private Limited
# 6                Not Available                            Not Available
# 7      Python Developer Intern                     Cognition Technology
# 8                       Python                                  Virtusa
# 9             Python Developer                                TachyonHR
#
#                          Salary                          Location
# 0                  Not Provided                     Not Available
# 1                  Not Provided  Hybrid work in Pune, Maharashtra
# 2       Up to ₹13,00,000 a year        Bavdhan, Pune, Maharashtra
# 3  ₹3,00,000 - ₹7,00,000 a year                 Pune, Maharashtra
# 4  ₹4,00,000 - ₹7,00,000 a year                 Pune, Maharashtra
# 5                  Not Provided                 Pune, Maharashtra
# 6                  Not Provided                     Not Available
# 7         From ₹1,20,000 a year      Chinchwad, Pune, Maharashtra
# 8                     Full-time  Hybrid work in Pune, Maharashtra
# 9     ₹20,000 - ₹35,000 a month       Wanowrie, Pune, Maharashtra
